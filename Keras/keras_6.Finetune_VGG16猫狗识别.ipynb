# %% [markdown]
# ## 1.导入需要的包

# %%
import numpy as np
from keras.applications.vgg16 import VGG16
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Activation,Dropout,Flatten,Dense
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2.VGG模型

# %%
VGG16_model = VGG16(weights='imagenet',include_top=False, input_shape=(150,150,3))
# Out:
# WARNING:tensorflow:From C:\Users\Peco\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## 3.修改全连接层

# %%
top_model = Sequential()
top_model.add(Flatten(input_shape=VGG16_model.output_shape[1:]))
top_model.add(Dense(256,activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(2,activation='softmax'))

model = Sequential()
model.add(VGG16_model)
model.add(top_model)
# Out:
# WARNING:tensorflow:From C:\Users\Peco\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ## 4.数据集

# %%
train_datagen = ImageDataGenerator(
    rotation_range = 40,width_shift_range = 0.2,height_shift_range = 0.2, rescale = 1/255,shear_range = 20,
    zoom_range = 0.2,horizontal_flip = True,fill_mode = 'nearest',) 
test_datagen = ImageDataGenerator(
    rescale = 1/255,         # 数据归一化
)

# %%
batch_size = 32

# train_data
train_generator = train_datagen.flow_from_directory(
    'catVSdog/train',
    target_size=(150,150),
    batch_size=batch_size)

# test_data
test_generator = test_datagen.flow_from_directory(
    'catVSdog/test',
    target_size=(150,150),
    batch_size=batch_size )
# Out:
# Found 400 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# ## 5.训练

# %%
# train
model.compile(optimizer=SGD(lr=1e-4,momentum=0.9),loss='categorical_crossentropy',metrics=['accuracy'])
model.fit_generator(train_generator,steps_per_epoch=len(train_generator),
                    epochs=20,validation_data=test_generator,
                    validation_steps=len(test_generator))
# Out:
# WARNING:tensorflow:From C:\Users\Peco\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 13/13 [==============================] - 315s 24s/step - loss: 0.8751 - acc: 0.5262 - val_loss: 0.7611 - val_acc: 0.5000
# Epoch 2/20
# 13/13 [==============================] - 295s 23s/step - loss: 0.7427 - acc: 0.5694 - val_loss: 0.6358 - val_acc: 0.6400
# Epoch 3/20
# 13/13 [==============================] - 294s 23s/step - loss: 0.7166 - acc: 0.5597 - val_loss: 0.6179 - val_acc: 0.6950
# Epoch 4/20
# 13/13 [==============================] - 295s 23s/step - loss: 0.6763 - acc: 0.6078 - val_loss: 0.6006 - val_acc: 0.6800
# Epoch 5/20
# 13/13 [==============================] - 296s 23s/step - loss: 0.6114 - acc: 0.6588 - val_loss: 0.5651 - val_acc: 0.7300
# Epoch 6/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.6064 - acc: 0.6634 - val_loss: 0.5838 - val_acc: 0.6450
# Epoch 7/20
# 13/13 [==============================] - 291s 22s/step - loss: 0.5769 - acc: 0.7162 - val_loss: 0.5133 - val_acc: 0.7600
# Epoch 8/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.5474 - acc: 0.7216 - val_loss: 0.4972 - val_acc: 0.7400
# Epoch 9/20
# 13/13 [==============================] - 293s 23s/step - loss: 0.4839 - acc: 0.7980 - val_loss: 0.4693 - val_acc: 0.7550
# Epoch 10/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.4977 - acc: 0.7385 - val_loss: 0.4406 - val_acc: 0.7750
# Epoch 11/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.4479 - acc: 0.7839 - val_loss: 0.4083 - val_acc: 0.8050
# Epoch 12/20
# 13/13 [==============================] - 293s 23s/step - loss: 0.4918 - acc: 0.7691 - val_loss: 0.3806 - val_acc: 0.8300
# Epoch 13/20
# 13/13 [==============================] - 293s 23s/step - loss: 0.4036 - acc: 0.8177 - val_loss: 0.3615 - val_acc: 0.8200
# Epoch 14/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.4118 - acc: 0.7910 - val_loss: 0.3566 - val_acc: 0.8200
# Epoch 15/20
# 13/13 [==============================] - 293s 23s/step - loss: 0.3901 - acc: 0.8197 - val_loss: 0.3326 - val_acc: 0.8350
# Epoch 16/20
# 13/13 [==============================] - 296s 23s/step - loss: 0.3712 - acc: 0.8318 - val_loss: 0.3378 - val_acc: 0.8150
# Epoch 17/20
# 13/13 [==============================] - 323s 25s/step - loss: 0.3625 - acc: 0.8268 - val_loss: 0.3069 - val_acc: 0.8600
# Epoch 18/20
# 13/13 [==============================] - 291s 22s/step - loss: 0.3755 - acc: 0.8485 - val_loss: 0.2933 - val_acc: 0.8650
# Epoch 19/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.3182 - acc: 0.8516 - val_loss: 0.2957 - val_acc: 0.8750
# Epoch 20/20
# 13/13 [==============================] - 292s 22s/step - loss: 0.3392 - acc: 0.8657 - val_loss: 0.2868 - val_acc: 0.8900

# %% [markdown]
# ## 6.保存模型

# %%
model.save('model_vgg16.h5')

# %% [markdown]
# ## 7.预测

# %%
from keras.models import load_model
import matplotlib.pyplot as plt
#加载模型
label = np.array(['猫','狗'])
model = load_model('model_vgg16.h5')
def pred(img):
    image = load_img(img)
    plt.imshow(image)
    image = image.resize((150,150))
    image = img_to_array(image)
    image = image/255
    image = np.expand_dims(image,0)
    image.shape
    print(label[model.predict_classes(image)])

# %%
pred('dog.jpg')
# Out:
# ['狗']

# %%
pred('cat.jpg')
# Out:
# ['猫']
